# %%
import pandas as pd
df = pd.read_csv('iris.csv')
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df['sepal.length'].argmax()
# Out:
# 131

# %%
df['sepal.length'>='4']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df['sepal.length'>='4']
#
# ...

# %%
df[df['sepal.length']>5.5]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 14            5.8          4.0           1.2          0.2      Setosa
# 15            5.7          4.4           1.5          0.4      Setosa
# 18            5.7          3.8           1.7          0.3      Setosa
# 50            7.0          3.2           4.7          1.4  Versicolor
# 51            6.4          3.2           4.5          1.5  Versicolor
# ..            ...          ...           ...          ...         ...
# 145           6.7          3.0           5.2          2.3   Virginica
# 146           6.3          2.5           5.0          1.9   Virginica
# 147           6.5          3.0           5.2          2.0   Virginica
# 148           6.2          3.4           5.4          2.3   Virginica
# 149           5.9          3.0           5.1          1.8   Virginica
#
# [91 rows x 5 columns]

# %%
df['variety'][df['sepal.length']>7.5]
# Out:
# 105    Virginica
# 117    Virginica
# 118    Virginica
# 122    Virginica
# 131    Virginica
# 135    Virginica
# Name: variety, dtype: object

# %%
df['sepal.width'].mean()
# Out:
# 3.0573333333333337

# %%
df[df['sepal.length']>6.7][df['sepal.width']>3]
# Out:
# C:\Users\jayen\AppData\Local\Temp\ipykernel_126612\2762456697.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['sepal.length']>6.7][df['sepal.width']>3]
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 50            7.0          3.2           4.7          1.4  Versicolor
# 52            6.9          3.1           4.9          1.5  Versicolor
# 109           7.2          3.6           6.1          2.5   Virginica
# 117           7.7          3.8           6.7          2.2   Virginica
# 120           6.9          3.2           5.7          2.3   Virginica
# 125           7.2          3.2           6.0          1.8   Virginica
# 131           7.9          3.8           6.4          2.0   Virginica
# 139           6.9          3.1           5.4          2.1   Virginica
# 141           6.9          3.1           5.1          2.3   Virginica
# 143           6.8          3.2           5.9          2.3   Virginica

# %%
df[df['sepal.length']>6.7 & df['sepal.width']>3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\ops\array_ops.py:364, in na_logical_op(x, y, op)
#     355 try:
#     356     # For exposition, write:
#     357     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     362     # Then Cases where this goes through without raising include:
#     363     #  (xint or xbool) and (yint or bool)
# --> 364     result = op(x, y)
#     365 except TypeError:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\roperator.py:54, in rand_(left, right)
#      53 def rand_(left, right):
# ---> 54     return operator.and_(right, left)
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# ...

# %%
df[((df['sepal.length']>5) | (df['sepal.width']>3)) & (df['variety']=='Setosa')]
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 0            5.1          3.5           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 14           5.8          4.0           1.2          0.2  Setosa
# 15           5.7          4.4           1.5          0.4  Setosa
# 16           5.4          3.9           1.3          0.4  Setosa
# ...

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df[3:8]
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa

# %%
df['sepal.length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal.length, Length: 150, dtype: float64

# %%
df[df['sepal.length']>0]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df[['sepal.length','sepal.width']].describe()
# Out:
#        sepal.length  sepal.width
# count    150.000000   150.000000
# mean       5.843333     3.057333
# std        0.828066     0.435866
# min        4.300000     2.000000
# 25%        5.100000     2.800000
# 50%        5.800000     3.000000
# 75%        6.400000     3.300000
# max        7.900000     4.400000

# %%
df[df['sepal.length']==df['sepal.length'].max()]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 131           7.9          3.8           6.4          2.0  Virginica
